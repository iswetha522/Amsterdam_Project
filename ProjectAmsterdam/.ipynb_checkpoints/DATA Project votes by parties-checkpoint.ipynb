# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/Users/michelle/Documents/Ironhack Project Amsterdam'

# %%
votes_2002 = pd.read_csv('2002_jaarboek.csv', skiprows=0, sep=';', usecols=[0,1,2,3,5], na_filter=False)

votes_2002
# Out:
#    Verkiezingen Gemeenteraad 2002 en 1998, Amsterdam Unnamed: 1  \
# 0
# 1
# 2                               politieke groepering      lijst
# 3
# 4                               partij van de arbeid          1
# 5                                                vvd          2
# 6                                         groenlinks          3
# 7                                                d66          4
# 8                         sp (socialistische partij)          5
# 9                        christen democratisch appèl          6
# 10                       amsterdam anders/de groenen          7
# 11                                  mokum mobiel '99          8
# 12                                 rijdend nederland          9
# 13                    nationale democratische partij         10
# 14                    humanistische partij amsterdam         11
# 15                                  amsterdam leeft!         12
# 16                           nieuwe nationale partij         13
# 17                         jongeren partij nederland         14
# 18                      nieuwe communistische partij         15
# 19                                      christenunie         16
# 20                                      actieve stad         18
# 21                          leefbaar amsterdam la 92         19
# 22                    arabische democratische partij         20
# 23                                        toekomst21         21
# 24                                   vorige partijen
# 25                     totaal geldige stemmen/zetels
# 26                             niet-kiezende kiezers
# 27                                  kiesgerechtigden
# 28                                 opkomstpercentage
# 29
# 30
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 5
# 0
# 1                       absoluut  procenten
# 2   pol. gr. afgekort     GR2002     GR2002
# 3
# 4                PVDA      77792       28,6
# 5                 VVD      48804       18,0
# 6             GRLINKS      35197       13,0
# 7                 D66      19600        7,2
# 8                  SP      20777        7,7
# 9                 CDA      21460        7,9
# 10              AA/DG       9590        3,5
# 11               MM99       6123        2,3
# 12              RIJDN        722        0,3
# 13                NDP        593        0,2
# 14                 HP        900        0,3
# 15              LEEFT       4630        1,7
# 16                NNP        773        0,3
# 17                JPN        420        0,2
# 18               NCPN        819        0,3
# 19              CHRUN       3719        1,4
# 20              ACSTD       2758        1,0
# 21               LA92      13958        5,1
# 22                ADP        922        0,3
# 23                T21       2028        0,7
# 24
# 25                        271585        100
# 26                        296953
# 27                        568538
# 28                                     47,8
# 29
# 30

# %%
# votes_2002_zetels = pd.read_csv('2002_jaarboek_zetels.csv', skiprows=0, usecols=[0,1,7], sep=';', na_filter=False)

# votes_2002_zetels

# %%
votes_2006 = pd.read_csv('2006_gemeenteraad.csv', skiprows=0, usecols=[0,1,2,4,6], sep=';', na_filter=False)

votes_2006
# Out:
#    Tabel 1  Verkiezingen Gemeenteraad Amsterdam 2006 Unnamed: 1  \
# 0
# 1
# 2                               politieke groepering      lijst
# 3
# 4                    Partij van de Arbeid (P.v.d.A.)          1
# 5                                                VVD       2 1)
# 6                                         GROENLINKS          3
# 7                  Christen Democratisch Appèl (CDA)          4
# 8                         SP (Socialistische Partij)          5
# 9                                Democraten 66 (D66)       6 1)
# 10                         LEEFBAAR AMSTERDAM L A 92          7
# 11                       AMSTERDAM ANDERS/De Groenen          8
# 12                                      Mokum Mobiel          9
# 13                     Partij van de Toekomst (PvdT)         10
# 14                              PARTIJ VAN AMSTERDAM         11
# 15                                 AMSTERDAM LEEFT !      12 2)
# 16             Humanistische Partij Amsterdam (H.P.)         13
# 17                                  AMSTERDAM LOKAAL         14
# 18                 FVP / Ouderenpartij Noord-Holland         15
# 19                 Nieuwe Communistische Partij-NCPN         16
# 20            VIP Vooruitstrevende Integratie Partij         17
# 21                                      ChristenUnie         18
# 22                                DUURZAAM NEDERLAND         19
# 23                                Liberaal Amsterdam         20
# 24                             Amsterdam Transparant         21
# 25                            HUISJE-BOOMPJE-BEESTJE      22 2)
# 26              NATIONALE DEMOCRATISCHE PARTIJ (NDP)         23
# 27                     Conservatieve Democraten (CD)         24
# 28                                   vorige partijen
# 29                     totaal geldige stemmen/zetels
# 30                                    blanco stemmen
# 31                           totaal + blanco stemmen
# 32                                  kiesgerechtigden
# 33                                 opkomstpercentage
# 34
# 35                    1) lijstcombinatie VVD en D66.
# 36               2) lijstcombinatie ASDLEEFT en HBB.
#
#            Unnamed: 2 Unnamed: 4 Unnamed: 6
# 0
# 1
# 2   pol. gr. afgekort       2006       2006
# 3
# 4                PVDA     119651       39,4
# 5                 VVD      49172       16,2
# 6                  GL      41563       13,7
# 7                 CDA      12715        4,2
# 8                  SP      40637       13,4
# 9                 D66      12338        4,1
# 10              LA 92       4098        1,3
# 11              AA/DG       5935        2,0
# 12                 MM       1740        0,6
# 13               PVDT       1419        0,5
# 14              PVASD       1043        0,3
# 15           ASDLEEFT        819        0,3
# 16                 HP        760        0,3
# 17             ASDLOK        891        0,3
# 18           FVP/OPNH       1804        0,6
# 19               NCPN        511        0,2
# 20                VIP        325        0,1
# 21            CHRUNIE       4433        1,5
# 22           DUURZNED        662        0,2
# 23             LIBASD        784        0,3
# 24             ASDTRP        445        0,1
# 25                HBB        787        0,3
# 26                NDP        196        0,1
# 27                 CD       1124        0,4
# 28
# 29                        303852        100
# 30                          1382
# 31                        305234
# 32                        579276
# 33                                     52,7
# 34
# 35
# 36

# %%
# votes_2006_zetels = pd.read_csv('2006_jaarboek.csv', skiprows=0, sep=';', usecols=[0,1,8], na_filter=False)

# votes_2006_zetels

# %%
votes_2010 = pd.read_csv('2010_jaarboek.csv', sep=';', na_filter=False, usecols=[0,1,3,5])

votes_2010
# Out:
#    16.1.1  Uitgebrachte geldige stemmen, blanco/ongeldige stemmen, kiesgerechtigden en opkomstpercentage bij de verkiezingen voor de Gemeenteraad, 2006 en 2010  \
# 0
# 1
# 2                                politieke groepering
# 3
# 4                     Partij van de Arbeid (P.v.d.A.)
# 5                                                 VVD
# 6                                          GROENLINKS
# 7                          SP (Socialistische Partij)
# 8                   Christen Democratisch Appèl (CDA)
# 9                                 Democraten 66 (D66)
# 10                              Tulpen voor Amsterdam
# 11                                      RED AMSTERDAM
# 12                         Partij voor Mens en Spirit
# 13                     Amsterdamsche Belangen (AB) 1)
# 14                                      De Groenen 2)
# 15              TROTS OP NEDERLAND LIJST RITA VERDONK
# 16                              Partij voor de Dieren
# 17               NATIONALE DEMOCRATISCHE PARTIJ (NDP)
# 18                       Republikeinse Moderne Partij
# 19                                       ChristenUnie
# 20                                 LEEFBAAR AMSTERDAM
# 21                                  Amsterdam Sociaal
# 22                                           Lijst 19
# 23                                       Mokum Mobiel
# 24                      Partij van de Toekomst (PvdT)
# 25                                  AMSTERDAM LEEFT !
# 26              Humanistische Partij Amsterdam (H.P.)
# 27                                   AMSTERDAM LOKAAL
# 28                  FVP / Ouderenpartij Noord-Holland
# 29                  Nieuwe Communistische Partij-NCPN
# 30             VIP Vooruitstrevende Integratie Partij
# 31                                 DUURZAAM NEDERLAND
# 32                                 Liberaal Amsterdam
# 33                              Amsterdam Transparant
# 34                             HUISJE-BOOMPJE-BEESTJE
# 35                      Conservatieve Democraten (CD)
# 36                             totaal geldige stemmen
# 37                           blanco/ongeldige stemmen
# 38                                     totaal stemmen
# 39                                   kiesgerechtigden
# 40                                  opkomstpercentage
# 41
# 42                    1) 2006 = PARTIJ VAM AMSTERDAM.
# 43             2) 2006 = AMSTERDAM ANDERS/De Groenen.
#
#            Unnamed: 1 Unnamed: 3     Unnamed: 5
# 0
# 1
# 2   pol. gr. afgekort       2010           2010
# 3
# 4                PVDA      90067           29,3
# 5                 VVD      52039           16,9
# 6                  GL      46407           15,1
# 7                  SP      22266            7,2
# 8                 CDA      10218            3,3
# 9                 D66      45524           14,8
# 10                TVA       1230            0,4
# 11             REDASD      11435            3,7
# 12               MENS       1009            0,3
# 13                 AB       1315            0,4
# 14              AA/DG       2001            0,7
# 15           TROTSOPN       7096            2,3
# 16               PVDD       7113            2,3
# 17                NDP        543            0,2
# 18                RMP        215            0,1
# 19                 CU       3860            1,3
# 20                 LA       3079            1,0
# 21             ASDSOC       1181            0,4
# 22                L19        696            0,2
# 23                 MM
# 24               PVDT
# 25           ASDLEEFT
# 26                 HP
# 27             ASDLOK
# 28           FVP/OPNH
# 29               NCPN
# 30                VIP
# 31              DUURZ
# 32             LIBASD
# 33             ASDTRP
# 34                HBB
# 35                 CD
# 36                        307294            100
# 37                          3355
# 38                        310649
# 39                        604583
# 40                                         51,4
# 41
# 42                                bron: DBI/O+S
# 43

# %%
# votes_2010_zetels = pd.read_csv('2010_jaarboek_zetels.csv', skiprows=0, sep=';', usecols=[0,1,9], na_filter=False)

# votes_2010_zetels

# %%
votes_2014 = pd.read_csv('2014_jaarboek.csv', sep=';', na_filter=False, usecols=[0,1,3,5])

votes_2014
# Out:
#    11.3.1  Uitgebrachte geldige stemmen, blanco/ongeldige stemmen, kiesgerechtigden en opkomstpercentage bij de verkiezingen voor de Gemeenteraad, 2010 en 2014  \
# 0
# 1
# 2                                politieke groepering
# 3
# 4                  Partij van de Arbeid (P.v.d.A.) 1)
# 5                                              VVD 2)
# 6                                       GROENLINKS 1)
# 7                              Democraten 66 (D66) 2)
# 8                          SP (Socialistische Partij)
# 9                                    RED AMSTERDAM 3)
# 10                                                CDA
# 11                           Partij voor de Dieren 3)
# 12                                         TROTS 4)5)
# 13                                       lijst Thonon
# 14                                      Piratenpartij
# 15                                         De Groenen
# 16                     Ouderen Partij Amsterdam (OPA)
# 17                                  Amsterdam Sociaal
# 18                                      ChristenUnie
# 19                                 LEEFBAAR AMSTERDAM
# 20               De Republikeinse Politieke Partij 6)
# 21             Partij Voor Vrije Amsterdammers (PVVA)
# 22               Radicale Oppositie Beweging (R.O.B.)
# 23                  Nieuwe Amsterdamse Toekomst (NAT)
# 24                                      OMA Amsterdam
# 25                    Multicultureel Plus Partij (M+)
# 26                         Basis Inkomen Partij (BIP)
# 27             Visie Op Amsterdam (Lijst Ina Brouwer)
# 28                              Partij van de Eenheid
# 29                Partij van de Ouderen (P.v.d.O.) 4)
# 30                          Libertarische Partij (LP)
# 31                              Tulpen voor Amsterdam
# 32                         Partij voor Mens en Spirit
# 33                        Amsterdamsche Belangen (AB)
# 34               NATIONALE DEMOCRATISCHE PARTIJ (NDP)
# 35                                           Lijst 19
# 36                             totaal geldige stemmen
# 37                           blanco/ongeldige stemmen
# 38                                     totaal stemmen
# 39                                   kiesgerechtigden
# 40                                  opkomstpercentage
# 41
# 42                 1) Combinatie PVDA met GROENLINKS.
# 43                         2) Combinatie VVD met D66.
# 44                     3) Combinatie REDASD met PVDD.
# 45                      4) Combinatie TROTS met PVDO.
# 46    5) 2010 = TROTS OP NEDERLAND LIJST RITA VERDONK
# 47             6) 2010 = Republikeinse Moderne Partij
#
#            Unnamed: 1 Unnamed: 3                      Unnamed: 5
# 0
# 1
# 2   pol. gr. afgekort       2014                            2014
# 3
# 4                PVDA      58461                            18,4
# 5                 VVD      35639                            11,2
# 6            GROENLIN      34145                            10,7
# 7                 D66      85241                            26,8
# 8                  SP      35627                            11,2
# 9              REDASD       5038                             1,6
# 10                CDA       8852                             2,8
# 11               PVDD       8944                             2,8
# 12              TROTS       1200                             0,4
# 13                 −−        130                             0,0
# 14           PIRATENP       5606                             1,8
# 15            GROENEN       1427                             0,4
# 16            OPA-ASD       3891                             1,2
# 17             ASDSOC        697                             0,2
# 18                 CU       5625                             1,8
# 19                 LA       2675                             0,8
# 20                RPP        174                             0,1
# 21               PVVA       3912                             1,2
# 22                ROB        711                             0,2
# 23                NAT       1506                             0,5
# 24                OMA       1063                             0,3
# 25                MPP       4319                             1,4
# 26                BIP        602                             0,2
# 27                VOA        600                             0,2
# 28               PVDE       4231                             1,3
# 29               PVDO       6762                             2,1
# 30                 LP        667                             0,2
# 31                TVA
# 32               MENS
# 33                 AB
# 34                NDP
# 35                L19
# 36                        317745                             100
# 37                          5193
# 38                        322938
# 39                        642286
# 40                                                          50,3
# 41
# 42                                bron: afd. Basisinformatie/OIS
# 43
# 44
# 45
# 46
# 47

# %%
# votes_2014_zetels = pd.read_csv('2014_jaarboek_zetels.csv', skiprows=0, sep=';', na_filter=False)

# votes_2014_zetels

# %%
votes_2018 = pd.read_csv('2018_jaarboek.csv', sep=';', na_filter=False, usecols=[0,1,3,5])

votes_2018
# Out:
#    11.3.1  Uitgebrachte geldige stemmen, blanco/ongeldige stemmen, kiesgerechtigden en opkomstpercentage bij de verkiezingen voor de Gemeenteraad, 2014 en 2018  \
# 0
# 1
# 2                                politieke groepering
# 3
# 4                                 Democraten 66 (D66)
# 5                     Partij van de Arbeid (P.v.d.A.)
# 6                                                 VVD
# 7                          SP (Socialistische Partij)
# 8                                          GROENLINKS
# 9                               Partij voor de Dieren
# 10                                                CDA
# 11                   Partij van de Ouderen (P.v.d.O.)
# 12                                               DENK
# 13                                 Platform Amsterdam
# 14                                  destemvandestraat
# 15                            Piratenpartij Amsterdam
# 16            Staatkundig Gereformeerde Partij  (SGP)
# 17                              Forum voor Democratie
# 18                        U-Buntu Connected Front UCF
# 19                     Basisinkomen Partij (BIpartij)
# 20     Blanco lijst (met 1e kandidaat van Oudenallen)
# 21                               Partij voor Iedereen
# 22                                       ChristenUnie
# 23                                     Amsterdam BIJ1
# 24            SAMEN Alle Mensen Één Nederland (SAMEN)
# 25                                Anti-Scooter Partij
# 26                                      Blije Burgers
# 27                                     Carryonthemove
# 28                                              QUEER
# 29                                             50PLUS
# 30                  De Republikeinse Politieke Partij
# 31          Blanco lijst (met 1e kandidaat Berendsen)
# 32                                      RED AMSTERDAM
# 33                    Multicultureel Plus Partij (M+)
# 34                              Partij van de Eenheid
# 35             Partij Voor Vrije Amsterdammers (PVVA)
# 36                     Ouderen Partij Amsterdam (OPA)
# 37                                 LEEFBAAR AMSTERDAM
# 38                  Nieuwe Amsterdamse Toekomst (NAT)
# 39                                         De Groenen
# 40                                              TROTS
# 41                                      OMA Amsterdam
# 42               Radicale Oppositie Beweging (R.O.B.)
# 43                                  Amsterdam Sociaal
# 44                          Libertarische Partij (LP)
# 45             Visie Op Amsterdam (Lijst Ina Brouwer)
# 46                                       lijst Thonon
# 47                             totaal geldige stemmen
# 48                           blanco/ongeldige stemmen
# 49                                     totaal stemmen
# 50                                   kiesgerechtigden
# 51                                  opkomstpercentage
# 52
# 53
#
#            Unnamed: 1 Unnamed: 3                      Unnamed: 5
# 0
# 1
# 2   pol. gr. afgekort       2018                            2018
# 3
# 4                 D66      55724                            16,1
# 5                PvdA      37181                            10,7
# 6                 VVD      39702                            11,4
# 7                  SP      26070                             7,5
# 8                  GL      70880                            20,4
# 9                PvdD      24672                             7,1
# 10                CDA      11991                             3,5
# 11               PvdO       7752                             2,2
# 12               DENK      23138                             6,7
# 13          PlatfAsd        1407                             0,4
# 14          StemvdStr        899                             0,3
# 15              PPAsd       4459                             1,3
# 16                SGP        546                             0,2
# 17                FvD      20015                             5,8
# 18                UCF       1052                             0,3
# 19           BIpartij        635                             0,2
# 20            Lijst17        281                             0,1
# 21            PvIeder        228                             0,1
# 22                 CU       6837                             2,0
# 23               BIJ1       6571                             1,9
# 24              SAMEN       1158                             0,3
# 25          A-SPartij        696                             0,2
# 26          BlijeBurg        318                             0,1
# 27           CarryotM        126                             0,0
# 28              QUEER        228                             0,1
# 29             50Plus       4233                             1,2
# 30               DRPP         89                             0,0
# 31            Lijst28        260                             0,1
# 32             REDASD
# 33                MPP
# 34               PVDE
# 35               PVVA
# 36            OPA-ASD
# 37                 LA
# 38                NAT
# 39            GROENEN
# 40              TROTS
# 41                OMA
# 42                ROB
# 43             ASDSOC
# 44                 LP
# 45                VOA
# 46                 −−
# 47                        347148                             100
# 48                          4510
# 49                        351658
# 50                        674286
# 51                                                          52,2
# 52
# 53                                bron: afd. Basisinformatie/OIS

# %%
votes_2018_zetels = pd.read_csv('2018_jaarboek_zetels.csv', skiprows=0, sep=';', na_filter=False)

votes_2018_zetels
# Out:
#    11.3.5  Zetelverdeling van de Gemeenteraad naar de politieke groeperingen en opkomstpercentage, 1994-2018  \
# 0
# 1                                politieke groepering
# 2
# 3                                 Democraten 66 (D66)
# 4                                Partij van de Arbeid
# 5                                                 VVD
# 6                          SP (Socialistische Partij)
# 7                                          GROENLINKS
# 8                               Partij voor de Dieren
# 9                         Christen Democratisch Appèl
# 10                              Partij van de Ouderen
# 11                                               DENK
# 12                              Forum voor Democratie
# 13                                       ChristenUnie
# 14                                     Amsterdam BIJ1
# 15                                      RED AMSTERDAM
# 16                                              TROTS
# 17                                 LEEFBAAR AMSTERDAM
# 18                        AMSTERDAM ANDERS/De Groenen
# 19                                       Mokum Mobiel
# 20                                  Centrumdemocraten
# 21                                             totaal
# 22                                  opkomstpercentage
# 23
# 24
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0
# 1        1994       1998       2002       2006       2010       2014
# 2
# 3           8          4          3          2          7         14
# 4          14         15         15         20         15         10
# 5           8          9          9          8          8          6
# 6           1          3          4          6          3          6
# 7           6          7          6          7          7          6
# 8                                                       1          1
# 9           3          3          4          2          2          1
# 10                                                                 1
# 11
# 12
# 13
# 14
# 15                                                      1
# 16                                                      1
# 17                                2
# 18          1          3          1
# 19                     1          1
# 20          4
# 21         45         45         45         45         45         45
# 22       56,9       47,2       47,8       52,7       51,4       50,3
# 23
# 24
#
#                         Unnamed: 7
# 0
# 1                             2018
# 2
# 3                                8
# 4                                5
# 5                                6
# 6                                3
# 7                               10
# 8                                3
# 9                                1
# 10                               1
# 11                               3
# 12                               3
# 13                               1
# 14                               1
# 15
# 16
# 17
# 18
# 19
# 20
# 21                              45
# 22                            52,2
# 23
# 24  bron: afd. Basisinformatie/OIS
